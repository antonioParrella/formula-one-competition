# %%
import sys
from pathlib import Path
# Use the folder containing this repo
PROJECT_ROOT = Path(r"C:\Users\parre\OneDrive\Documents\OneDrive\formula-one-competition")
sys.path.insert(0, str(PROJECT_ROOT / "src"))
from fetch_results import ResultsFetcher
from leaderboard import ResultAggregator

import os
print("CWD:", os.getcwd())
# Out:
# CWD: c:\Users\parre\OneDrive\Documents\OneDrive\formula-one-competition\notebooks

# %%
fetcher = ResultsFetcher(round_num=4, year=2026)

aggregator = ResultAggregator(round_number=4, year=2026)
# Out:
# Fetching data from: https://api.openf1.org/v1/sessions?year=2026
# Fetching data from: https://api.openf1.org/v1/session_result?session_key=11280
# Fetching data from: https://api.openf1.org/v1/championship_drivers?session_key=11280
# Fetching data from: https://api.openf1.org/v1/drivers?session_key=11280
# Fetching data from: https://api.openf1.org/v1/sessions?year=2026
# Fetching data from: https://api.openf1.org/v1/session_result?session_key=11280
# Fetching data from: https://api.openf1.org/v1/championship_drivers?session_key=11280
# Fetching data from: https://api.openf1.org/v1/drivers?session_key=11280

# %%
aggregator.race_calendar
# Out:
#     round_number  circuit_short_name session_name  meeting_key  session_key
# 0            1.0           Melbourne         Race         1279        11234
# 1            2.0            Shanghai         Race         1280        11245
# 2            3.0              Suzuka         Race         1281        11253
# 3            4.0               Miami         Race         1284        11280
# 4            5.0            Montreal         Race         1285        11291
# 5            6.0         Monte Carlo         Race         1286        11299
# 6            7.0           Catalunya         Race         1287        11307
# 7            8.0           Spielberg         Race         1288        11315
# 8            9.0         Silverstone         Race         1289        11326
# 9           10.0   Spa-Francorchamps         Race         1290        11334
# 10          11.0         Hungaroring         Race         1291        11342
# ...
